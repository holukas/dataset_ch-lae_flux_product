# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Flux Processing Chain (here starting Level-4.1)
# </b>
# </br>
#
# </span>
# <p>Post-processing of EddyPro <i>_fluxnet_</i> output files</p>

# %% [markdown]
# ---
# **Notebook version**: `11.0` (19 Nov 2025)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %%
import pickle
from datetime import datetime
from diive.core.io.files import save_parquet, load_parquet

# %% [markdown]
# </br>

# %% [markdown]
# # Load previous `fpc` instance

# %%
# 1. Load the instance from the pickle file
file_path = '02_fpcInstance_IRGA72_NEE-QCF10-UST165084-L3.3.pkl'
with open(file_path, 'rb') as file:
    fpc = pickle.load(file)

# %%
fpc

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🟢Level-4.1: GAP-FILLING

# %% [markdown]
# - Introduced in `diive` v0.85.0, gap-filling can now be done using both random forest and MDS
# - For gap-filling using MDS, make sure that variables are in the required units: short-wave incoming radiation in `W m-2`, air temperature in `°C`, VPD in `hPa`
#
# Parameters:
# - `mds_settings` are parameters for the MDS gap-filling method, [see docstring here for more details](https://github.com/holukas/diive/blob/main/diive/pkgs/gapfilling/mds.py)
# - `rf_settings` are parameters for scikit's `RandomForestRegressor` model, [see their official documentation for allowed parameters](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# - `ml_feature_settings` are general settings for machine-learning models (such as random forest)

# %% [markdown]
# ## 🔸Long-term random forest

# %%
FEATURES = ["TA_T1_47_1_gfXG", "SW_IN_T1_47_1_gfXG", "VPD_T1_47_1_gfXG"]
fpc.level41_longterm_random_forest(
    features=FEATURES,
    sanitize_timestamp=True,
    features_lag=[-1, -1],
    features_lag_stepsize=1,
    features_lag_exclude_cols=None,
    reduce_features=False,
    vectorize_timestamps=True,
    add_continuous_record_number=True,
    perm_n_repeats=10,
    verbose=True,
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    n_jobs=1,
    random_state=42,
)
# Out:
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Adding new data columns ...
# ++ Added new columns with lagged variants for: ['TA_T1_47_1_gfXG', 'SW_IN_T1_47_1_gfXG', 'VPD_T1_47_1_gfXG'] (lags between -1 and -1 with stepsize 1), no lagged variants for: ['NEE_L3.1_L3.3_CUT_16_QCF']. Shifting the time series created gaps which were then filled with the nearest value.
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
# ++ Added new column .RECORDNUMBER with record numbers from 1 to 157824.
#
# Sanitizing timestamp ...
# >>> Validating timestamp naming of timestamp column TIMESTAMP_MIDDLE ... Timestamp name OK.
# >>> Converting timestamp TIMESTAMP_MIDDLE to datetime ... OK
# >>> All rows have timestamp TIMESTAMP_MIDDLE, no rows removed.
# >>> Sorting timestamp TIMESTAMP_MIDDLE ascending ...
# >>> Removing data records with duplicate indexes ... OK (no duplicates found in timestamp index)
# >>> Creating continuous <30 * Minutes> timestamp index for timestamp TIMESTAMP_MIDDLE between 2016-01-01 00:15:00 and 2024-12-31 23:45:00 ...
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2018, 2019, 2020] to data pool for 2019.
# [neighboring_years] Assigned [2019, 2020, 2021] to data pool for 2020.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2021.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2022.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2023.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2024.
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2020 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2021 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2022 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2023 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2024 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_16_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Training model for 2016 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 12:45:00 and 2018-12-30 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2016 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34104 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2017 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 12:45:00 and 2018-12-30 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2017 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34104 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2018 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 08:45:00 and 2019-12-31 09:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2018 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 33173 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2019 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2018-01-09 15:45:00 and 2020-12-17 16:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2019 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 33240 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2020 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2019-01-01 09:45:00 and 2021-12-13 12:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2020 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 33219 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2021 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2020-01-01 16:15:00 and 2022-12-31 23:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2021 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 32200 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2022 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2021-01-04 23:45:00 and 2023-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2022 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 31815 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2023 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 12:15:00 and 2024-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2023 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 31258 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2024 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 12:15:00 and 2024-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_16_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2024 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_16_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_16_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 31258 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_16_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_16_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2016 ...
# Collecting results for 2017 ...
# Collecting results for 2018 ...
# Collecting results for 2019 ...
# Collecting results for 2020 ...
# Collecting results for 2021 ...
# Collecting results for 2022 ...
# Collecting results for 2023 ...
# Collecting results for 2024 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Adding new data columns ...
# ++ Added new columns with lagged variants for: ['TA_T1_47_1_gfXG', 'SW_IN_T1_47_1_gfXG', 'VPD_T1_47_1_gfXG'] (lags between -1 and -1 with stepsize 1), no lagged variants for: ['NEE_L3.1_L3.3_CUT_50_QCF']. Shifting the time series created gaps which were then filled with the nearest value.
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
# ++ Added new column .RECORDNUMBER with record numbers from 1 to 157824.
#
# Sanitizing timestamp ...
# >>> Validating timestamp naming of timestamp column TIMESTAMP_MIDDLE ... Timestamp name OK.
# >>> Converting timestamp TIMESTAMP_MIDDLE to datetime ... OK
# >>> All rows have timestamp TIMESTAMP_MIDDLE, no rows removed.
# >>> Sorting timestamp TIMESTAMP_MIDDLE ascending ...
# >>> Removing data records with duplicate indexes ... OK (no duplicates found in timestamp index)
# >>> Creating continuous <30 * Minutes> timestamp index for timestamp TIMESTAMP_MIDDLE between 2016-01-01 00:15:00 and 2024-12-31 23:45:00 ...
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2018, 2019, 2020] to data pool for 2019.
# [neighboring_years] Assigned [2019, 2020, 2021] to data pool for 2020.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2021.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2022.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2023.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2024.
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2020 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2021 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2022 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2023 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2024 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Training model for 2016 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 12:45:00 and 2018-12-30 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2016 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 35094 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2017 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 12:45:00 and 2018-12-30 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2017 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 35094 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2018 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 09:15:00 and 2019-12-30 13:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2018 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 34189 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2019 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2018-01-09 15:45:00 and 2020-12-17 13:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2019 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34220 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2020 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2019-01-01 09:45:00 and 2021-12-13 12:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2020 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34257 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2021 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2020-01-02 09:15:00 and 2022-12-31 23:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2021 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 33243 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2022 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2021-01-04 23:45:00 and 2023-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2022 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 32884 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2023 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 12:15:00 and 2024-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2023 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 32389 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2024 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 12:15:00 and 2024-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2024 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 32389 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2016 ...
# Collecting results for 2017 ...
# Collecting results for 2018 ...
# Collecting results for 2019 ...
# Collecting results for 2020 ...
# Collecting results for 2021 ...
# Collecting results for 2022 ...
# Collecting results for 2023 ...
# Collecting results for 2024 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Adding new data columns ...
# ++ Added new columns with lagged variants for: ['TA_T1_47_1_gfXG', 'SW_IN_T1_47_1_gfXG', 'VPD_T1_47_1_gfXG'] (lags between -1 and -1 with stepsize 1), no lagged variants for: ['NEE_L3.1_L3.3_CUT_84_QCF']. Shifting the time series created gaps which were then filled with the nearest value.
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
# ++ Added new column .RECORDNUMBER with record numbers from 1 to 157824.
#
# Sanitizing timestamp ...
# >>> Validating timestamp naming of timestamp column TIMESTAMP_MIDDLE ... Timestamp name OK.
# >>> Converting timestamp TIMESTAMP_MIDDLE to datetime ... OK
# >>> All rows have timestamp TIMESTAMP_MIDDLE, no rows removed.
# >>> Sorting timestamp TIMESTAMP_MIDDLE ascending ...
# >>> Removing data records with duplicate indexes ... OK (no duplicates found in timestamp index)
# >>> Creating continuous <30 * Minutes> timestamp index for timestamp TIMESTAMP_MIDDLE between 2016-01-01 00:15:00 and 2024-12-31 23:45:00 ...
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2018, 2019, 2020] to data pool for 2019.
# [neighboring_years] Assigned [2019, 2020, 2021] to data pool for 2020.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2021.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2022.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2023.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2024.
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2020 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2021 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2022 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2023 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2024 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_84_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Training model for 2016 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 12:45:00 and 2018-12-30 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2016 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 36234 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2017 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 12:45:00 and 2018-12-30 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2017 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 36234 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2018 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 13:15:00 and 2019-12-30 01:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2018 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 35379 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2019 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2018-01-09 15:45:00 and 2020-12-17 13:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2019 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 35387 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2020 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2019-01-01 09:45:00 and 2021-12-11 23:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2020 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 35499 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2021 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2020-01-02 20:15:00 and 2022-12-31 23:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2021 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34519 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2022 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2021-01-04 23:45:00 and 2023-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2022 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 34169 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2023 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 12:15:00 and 2024-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2023 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 33747 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2024 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 12:15:00 and 2024-12-31 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_84_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2024 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_84_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_84_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 33747 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_84_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_84_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2016 ...
# Collecting results for 2017 ...
# Collecting results for 2018 ...
# Collecting results for 2019 ...
# Collecting results for 2020 ...
# Collecting results for 2021 ...
# Collecting results for 2022 ...
# Collecting results for 2023 ...
# Collecting results for 2024 ...

# %% [markdown]
# ## 🔸MDS (Marginal Distribution Sampling)

# %%
# fpc.level41_mds(
#     swin="SW_IN_T1_47_1_gfXG",
#     ta="TA_T1_47_1_gfXG",
#     vpd="VPD_T1_47_1_gfXG",
#     swin_tol=[20, 50],
#     ta_tol=2.5,
#     vpd_tol=0.5,
#     avg_min_n_vals=5
# )

# %% [markdown]
# ## Get results
# - Results from the flux processing chain can be accessed using `.get_data()`
# - This returns a dataframe containing all input data and all newly generated variables, such as quality flags, quality-filtered fluxes and gap-filled fluxes

# %%
results = fpc.get_data(verbose=1)
results
# Out:
# NEW VARIABLES FROM FLUX PROCESSING CHAIN:
# ++ FLAG_L2_FC_MISSING_TEST
# ++ FLAG_L2_FC_SSITC_TEST
# ++ FLAG_L2_FC_SCF_TEST
# ++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST
# ++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST
# ++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST
# ++ SUM_L2_FC_HARDFLAGS
# ++ SUM_L2_FC_SOFTFLAGS
# ++ SUM_L2_FC_FLAGS
# ++ FLAG_L2_FC_QCF
# ++ FC_L2_QCF
# ++ FC_L2_QCF0
# ++ SC_SINGLE_gfRMED_L3.1
# ++ FLAG_SC_SINGLE_gfRMED_L3.1_ISFILLED
# ++ NEE_L3.1
# ++ NEE_L3.1_QCF
# ++ NEE_L3.1_QCF0
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_MANUAL_TEST
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST
# ++ SUM_L3.2_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.2_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.2_NEE_L3.1_FLAGS
# ++ FLAG_L3.2_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.2_QCF
# ++ NEE_L3.1_L3.2_QCF0
# ++ FLAG_L3.3_CUT_16_NEE_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_16_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_16_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_16_NEE_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_16_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.3_CUT_16_QCF
# ++ NEE_L3.1_L3.3_CUT_16_QCF0
# ++ FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_50_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_50_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_50_NEE_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_50_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.3_CUT_50_QCF
# ++ NEE_L3.1_L3.3_CUT_50_QCF0
# ++ FLAG_L3.3_CUT_84_NEE_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_84_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_84_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_84_NEE_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_84_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.3_CUT_84_QCF
# ++ NEE_L3.1_L3.3_CUT_84_QCF0
# ++ NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# ++ FLAG_NEE_L3.1_L3.3_CUT_16_QCF_gfRF_ISFILLED
# ++ NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# ++ FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfRF_ISFILLED
# ++ NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# ++ FLAG_NEE_L3.1_L3.3_CUT_84_QCF_gfRF_ISFILLED
# No variables in input data were overwritten, only new variables added.
#                       AIR_CP  AIR_DENSITY    AIR_MV  AIR_RHO_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  NEE_L3.1_L3.3_CUT_16_QCF_gfRF  FLAG_NEE_L3.1_L3.3_CUT_16_QCF_gfRF_ISFILLED  NEE_L3.1_L3.3_CUT_50_QCF_gfRF  FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfRF_ISFILLED  NEE_L3.1_L3.3_CUT_84_QCF_gfRF  FLAG_NEE_L3.1_L3.3_CUT_84_QCF_gfRF_ISFILLED
# TIMESTAMP_MIDDLE                                                                                   ...
# 2016-01-01 00:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                       3.820397                                            1                       3.144036                                            1                       3.039052                                            1
# 2016-01-01 00:45:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                       3.820397                                            1                       3.144036                                            1                       3.039052                                            1
# 2016-01-01 01:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                       4.519701                                            1                       3.751522                                            1                       3.541547                                            1
# 2016-01-01 01:45:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                       4.232698                                            1                       3.644648                                            1                       3.684616                                            1
# 2016-01-01 02:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                       3.720150                                            1                       3.442002                                            1                       3.388961                                            1
# ...                      ...          ...       ...         ...         ...                   ...  ...                            ...                                          ...                            ...                                          ...                            ...                                          ...
# 2024-12-31 21:45:00  1008.09      1.20135  0.024060     1211.07         0.0                   1.0  ...                       6.201621                                            1                       2.160376                                            1                       4.169302                                            1
# 2024-12-31 22:15:00  1008.14      1.20010  0.024085     1209.87         0.0                   1.0  ...                       5.464995                                            1                       1.628961                                            1                       4.387887                                            1
# 2024-12-31 22:45:00  1008.20      1.20023  0.024081     1210.07         0.0                   1.0  ...                       5.960608                                            1                       2.034185                                            1                       4.348215                                            1
# 2024-12-31 23:15:00  1008.19      1.19504  0.024186     1204.83         0.0                   1.0  ...                       5.700179                                            1                       2.101372                                            1                       4.186864                                            1
# 2024-12-31 23:45:00  1008.15      1.20042  0.024078     1210.20         0.0                   1.0  ...                       6.020623                                            1                       1.820026                                            1                       4.175692                                            1
#
# [157824 rows x 397 columns]

# %% [markdown]
# ## Model scores

# %% [markdown]
# ### Model scores and details on test data

# %%
# Show train/test details
print(fpc.report_traintest_model_scores())
print(fpc.report_traintest_details())
# fpc.report_traintest_model_scores(outpath=".")  # Save in current folder
# fpc.report_traintest_details(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES from TRAINING/TESTING (long_term_random_forest):
#  trained on training data, tested on unseen test data CUT_16
#             2016       2017       2018       2019       2020       2021       2022       2023       2024
# mae     3.564660   3.564660   3.641639   3.629596   3.607707   3.504323   3.501860   3.326474   3.326474
# medae   2.324670   2.324670   2.356981   2.294560   2.162194   2.210344   2.177259   2.126248   2.126248
# mse    28.775972  28.775972  29.367123  30.018469  31.450340  29.129318  29.330904  25.015380  25.015380
# rmse    5.364324   5.364324   5.419144   5.478911   5.608060   5.397158   5.415801   5.001538   5.001538
# mape    1.907389   1.907389   2.317378   2.491835   2.465694   1.838906   1.507555   1.771527   1.771527
# maxe   43.815463  43.815463  43.734400  48.327050  46.825448  44.406788  43.064633  40.681902  40.681902
# r2      0.738645   0.738645   0.726692   0.727294   0.729581   0.720004   0.733145   0.764789   0.764789
#
# MODEL SCORES from TRAINING/TESTING (long_term_random_forest):
#  trained on training data, tested on unseen test data CUT_50
#             2016       2017       2018       2019       2020       2021       2022       2023       2024
# mae     3.761754   3.761754   3.719829   3.662213   3.664636   3.490877   3.331403   3.357317   3.357317
# medae   2.409594   2.409594   2.425457   2.316659   2.275218   2.081728   2.090821   2.091179   2.091179
# mse    32.989909  32.989909  31.004005  30.307664  30.925689  29.640117  25.438380  26.458688  26.458688
# rmse    5.743684   5.743684   5.568124   5.505240   5.561087   5.444274   5.043648   5.143801   5.143801
# mape    1.645531   1.645531   1.890585   1.953542   1.777151   1.705066   2.206117   2.010555   2.010555
# maxe   48.996276  48.996276  37.986678  45.325285  42.078471  40.411438  40.307303  54.691275  54.691275
# r2      0.716695   0.716695   0.721459   0.732679   0.739962   0.722923   0.751315   0.751566   0.751566
#
# MODEL SCORES from TRAINING/TESTING (long_term_random_forest):
#  trained on training data, tested on unseen test data CUT_84
#             2016       2017       2018       2019       2020       2021       2022       2023       2024
# mae     3.653489   3.653489   3.710721   3.613831   3.708732   3.423157   3.418610   3.421209   3.421209
# medae   2.389621   2.389621   2.414733   2.327457   2.244795   2.110935   2.107149   2.163964   2.163964
# mse    30.293582  30.293582  30.466421  29.141783  32.644393  28.332646  27.361799  27.254892  27.254892
# rmse    5.503961   5.503961   5.519640   5.398313   5.713527   5.322842   5.230851   5.220622   5.220622
# mape    1.831089   1.831089   3.337195   1.982730   2.179619   1.588862   2.746046   1.943956   1.943956
# maxe   42.660774  42.660774  36.445035  47.280860  47.784238  46.438055  38.020202  41.906750  41.906750
# r2      0.737502   0.737502   0.733842   0.734536   0.729712   0.746338   0.748542   0.767238   0.767238
# None
#
# DETAILS from TRAINING/TESTING (long_term_random_forest CUT_16):
#  trained on training data, tested on unseen test data
#                                                         2016                                               2017                                               2018                                               2019                                               2020                                               2021                                               2022                                               2023                                               2024
# train_df                        TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_df                         TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_size                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25
# X_names    [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...
# model      (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...
#
# DETAILS from TRAINING/TESTING (long_term_random_forest CUT_50):
#  trained on training data, tested on unseen test data
#                                                         2016                                               2017                                               2018                                               2019                                               2020                                               2021                                               2022                                               2023                                               2024
# train_df                        TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_df                         TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_size                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25
# X_names    [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...
# model      (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...
#
# DETAILS from TRAINING/TESTING (long_term_random_forest CUT_84):
#  trained on training data, tested on unseen test data
#                                                         2016                                               2017                                               2018                                               2019                                               2020                                               2021                                               2022                                               2023                                               2024
# train_df                        TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_df                         TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_size                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25
# X_names    [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...
# model      (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...
# None

# %% [markdown]
# ### Model scores on all data

# %%
fpc.report_gapfilling_model_scores()
# fpc.report_gapfilling_model_scores(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES (long_term_random_forest): CUT_16
#             2016       2017       2018       2019       2020       2021       2022       2023       2024
# mae     1.897792   1.897792   1.933636   1.919266   1.943229   1.847823   1.825532   1.764864   1.764864
# medae   1.062948   1.062948   1.078124   1.054018   1.061419   0.980557   0.974289   0.961779   0.961779
# mse    10.278697  10.278697  10.526543  10.621669  11.266609  10.338849  10.268310   9.000078   9.000078
# rmse    3.206041   3.206041   3.244463   3.259090   3.356577   3.215408   3.204420   3.000013   3.000013
# mape    1.152548   1.152548   1.213949   1.186399   1.294158   1.031294   0.958412   1.127199   1.127199
# maxe   43.815463  43.815463  43.734400  48.327050  46.825448  44.406788  43.064633  40.681902  40.681902
# r2      0.906400   0.906400   0.902628   0.902983   0.903278   0.903073   0.902657   0.915754   0.915754
#
# MODEL SCORES (long_term_random_forest): CUT_50
#             2016       2017       2018       2019       2020       2021       2022       2023       2024
# mae     1.939317   1.939317   1.946361   1.922176   1.937716   1.845085   1.797293   1.762844   1.762844
# medae   1.068934   1.068934   1.079447   1.049330   1.049321   0.977740   0.976805   0.968855   0.968855
# mse    11.239265  11.239265  10.891462  10.710648  11.062189  10.445224   9.377463   9.257624   9.257624
# rmse    3.352501   3.352501   3.300222   3.272713   3.325987   3.231907   3.062264   3.042634   3.042634
# mape    1.052261   1.052261   1.121303   1.024065   1.081974   0.978844   1.065298   1.223249   1.223249
# maxe   48.996276  48.996276  37.986678  45.325285  42.078471  40.411438  40.307303  54.691275  54.691275
# r2      0.899718   0.899718   0.900921   0.903539   0.906190   0.903169   0.912120   0.914661   0.914661
#
# MODEL SCORES (long_term_random_forest): CUT_84
#             2016       2017       2018       2019       2020       2021       2022       2023       2024
# mae     1.913900   1.913900   1.941707   1.908789   1.953114   1.820701   1.804312   1.776770   1.776770
# medae   1.068729   1.068729   1.083888   1.045110   1.051402   0.985035   0.970658   0.970680   0.970680
# mse    10.620572  10.620572  10.692035  10.386003  11.471516  10.059914   9.751761   9.423055   9.423055
# rmse    3.258922   3.258922   3.269868   3.222732   3.386963   3.171737   3.122781   3.069699   3.069699
# mape    1.044041   1.044041   1.381097   1.104869   1.145517   0.935402   1.108585   1.108259   1.108259
# maxe   42.660774  42.660774  36.445035  47.280860  47.784238  46.438055  38.020202  41.906750  41.906750
# r2      0.907015   0.907015   0.904307   0.907640   0.904057   0.908346   0.910399   0.915034   0.915034

# %% [markdown]
# During long-term gap-filling, different years are pooled together to predict one central year, i.e., multiple models are used.
# The used data pools can be display with:

# %%
fpc.report_gapfilling_poolyears()
# Out:
# DATA POOLS USED FOR MACHINE-LEARNING GAP-FILLING:
# 2016: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2017: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2018: long_term_random_forest used data from [2017, 2018, 2019] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2019: long_term_random_forest used data from [2018, 2019, 2020] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2020: long_term_random_forest used data from [2019, 2020, 2021] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2021: long_term_random_forest used data from [2020, 2021, 2022] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2022: long_term_random_forest used data from [2021, 2022, 2023] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2023: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2024: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling NEE_L3.1_L3.3_CUT_16_QCF and producing --> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# 2016: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2017: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2018: long_term_random_forest used data from [2017, 2018, 2019] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2019: long_term_random_forest used data from [2018, 2019, 2020] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2020: long_term_random_forest used data from [2019, 2020, 2021] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2021: long_term_random_forest used data from [2020, 2021, 2022] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2022: long_term_random_forest used data from [2021, 2022, 2023] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2023: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2024: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2016: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# 2017: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# 2018: long_term_random_forest used data from [2017, 2018, 2019] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# 2019: long_term_random_forest used data from [2018, 2019, 2020] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# 2020: long_term_random_forest used data from [2019, 2020, 2021] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# 2021: long_term_random_forest used data from [2020, 2021, 2022] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# 2022: long_term_random_forest used data from [2021, 2022, 2023] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# 2023: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF
# 2024: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling NEE_L3.1_L3.3_CUT_84_QCF and producing --> NEE_L3.1_L3.3_CUT_84_QCF_gfRF

# %%
fpc.report_gapfilling_feature_importances()  # Save in current folder
# fpc.report_gapfilling_feature_importances(outpath=".")  # Save in current folder
# Out:
# FEATURE IMPORTANCES (long_term_random_forest): CUT_16
# YEAR                       2016      2017      2018      2019      2020      2021      2022      2023      2024
# FEATURE
# SW_IN_T1_47_1_gfXG     0.960791  0.960791  0.806984  0.682083  0.973036  0.639850  1.260371  1.211612  1.211612
# .DOY_COS               0.284454  0.284454  0.598960  0.480668  0.143511  0.135855  0.224070  0.347697  0.347697
# .HOUR_COS              0.268759  0.268759  0.328060  0.244218  0.184569  0.304868  0.189747  0.302562  0.302562
# .WEEK_COS              0.132154  0.132154  0.005458  0.006666  0.041522  0.158475  0.025179  0.031581  0.031581
# .VPD_T1_47_1_gfXG-1    0.131291  0.131291  0.109094  0.104618  0.092561  0.089046  0.093563  0.122712  0.122712
# VPD_T1_47_1_gfXG       0.071054  0.071054  0.076312  0.059126  0.058242  0.059853  0.065517  0.059095  0.059095
# .DOY_SIN               0.069841  0.069841  0.115649  0.038448  0.031982  0.037736  0.046908  0.060027  0.060027
# .SW_IN_T1_47_1_gfXG-1  0.068361  0.068361  0.083887  0.132068  0.144738  0.139925  0.087724  0.133455  0.133455
# .RECORDNUMBER          0.054908  0.054908  0.064247  0.055119  0.055119  0.039869  0.106378  0.030163  0.030163
# .TA_T1_47_1_gfXG-1     0.047670  0.047670  0.045422  0.044846  0.057077  0.055861  0.057897  0.048541  0.048541
# TA_T1_47_1_gfXG        0.040583  0.040583  0.036967  0.032169  0.042185  0.061821  0.037279  0.036654  0.036654
# .HOUR_SIN              0.032256  0.032256  0.038272  0.029036  0.027049  0.040291  0.049980  0.053413  0.053413
# .YEARDOY               0.016910  0.016910  0.017990  0.017111  0.019839  0.017526  0.020676  0.011728  0.011728
# .WEEK_SIN              0.009866  0.009866  0.004811  0.070842  0.048101  0.053600  0.006022  0.008683  0.008683
# .YEARWEEK              0.004371  0.004371  0.004965  0.005106  0.005690  0.005561  0.005061  0.004297  0.004297
# .MONTH_COS             0.002740  0.002740  0.002514  0.002372  0.003589  0.004282  0.003053  0.005606  0.005606
# .YEARMONTH             0.001660  0.001660  0.002128  0.001924  0.002234  0.002835  0.002106  0.001999  0.001999
# .MONTH_SIN             0.001132  0.001132  0.001964  0.001531  0.064471  0.008063  0.159919  0.030923  0.030923
# .SEASON_COS            0.000839  0.000839  0.000677  0.000752  0.022663  0.003588  0.006825  0.001186  0.001186
# .YEAR                  0.000530  0.000530  0.000778  0.000646  0.000711  0.001254  0.000612  0.000647  0.000647
# .SEASON_SIN            0.000202  0.000202  0.000269  0.000226  0.000477  0.000344  0.000276  0.000234  0.000234
#
# FEATURE IMPORTANCES (long_term_random_forest): CUT_50
# YEAR                       2016      2017      2018      2019      2020      2021      2022      2023      2024
# FEATURE
# SW_IN_T1_47_1_gfXG     0.875915  0.875915  0.749061  0.947941  0.821361  0.922566  1.257820  1.357444  1.357444
# .DOY_COS               0.349145  0.349145  0.566474  0.471191  0.151315  0.095990  0.258004  0.382509  0.382509
# .HOUR_COS              0.219757  0.219757  0.255136  0.219960  0.185086  0.217407  0.230976  0.279363  0.279363
# .VPD_T1_47_1_gfXG-1    0.135787  0.135787  0.135592  0.095059  0.087643  0.092951  0.097930  0.117589  0.117589
# .DOY_SIN               0.084936  0.084936  0.104613  0.039213  0.033147  0.028434  0.040298  0.063622  0.063622
# VPD_T1_47_1_gfXG       0.081276  0.081276  0.070159  0.053143  0.042407  0.050385  0.066021  0.057962  0.057962
# .WEEK_COS              0.080835  0.080835  0.004717  0.005593  0.046156  0.129727  0.030899  0.018658  0.018658
# .SW_IN_T1_47_1_gfXG-1  0.075422  0.075422  0.104378  0.124907  0.139974  0.120608  0.110495  0.138709  0.138709
# .RECORDNUMBER          0.056767  0.056767  0.060746  0.064887  0.056242  0.042519  0.135555  0.030053  0.030053
# .TA_T1_47_1_gfXG-1     0.043781  0.043781  0.043822  0.050436  0.045605  0.046393  0.057571  0.040258  0.040258
# TA_T1_47_1_gfXG        0.035132  0.035132  0.036040  0.036610  0.036192  0.064520  0.037909  0.027873  0.027873
# .HOUR_SIN              0.029473  0.029473  0.031838  0.026104  0.026559  0.036021  0.041412  0.043415  0.043415
# .YEARDOY               0.016312  0.016312  0.020614  0.015403  0.016042  0.015773  0.016529  0.010779  0.010779
# .WEEK_SIN              0.005179  0.005179  0.005774  0.059727  0.038435  0.028352  0.007711  0.006508  0.006508
# .YEARWEEK              0.004350  0.004350  0.004690  0.004300  0.006316  0.005409  0.004459  0.004261  0.004261
# .MONTH_COS             0.002508  0.002508  0.002694  0.003037  0.002433  0.002862  0.003172  0.004123  0.004123
# .YEARMONTH             0.001513  0.001513  0.001954  0.001837  0.002016  0.002095  0.001898  0.001681  0.001681
# .SEASON_COS            0.001144  0.001144  0.000646  0.000870  0.034739  0.007208  0.003376  0.001055  0.001055
# .MONTH_SIN             0.001120  0.001120  0.002181  0.001609  0.045160  0.044338  0.151219  0.039823  0.039823
# .YEAR                  0.000568  0.000568  0.000703  0.000564  0.000953  0.001013  0.000523  0.000591  0.000591
# .SEASON_SIN            0.000184  0.000184  0.000303  0.000269  0.000706  0.000234  0.000213  0.000215  0.000215
#
# FEATURE IMPORTANCES (long_term_random_forest): CUT_84
# YEAR                       2016      2017      2018      2019      2020      2021      2022      2023      2024
# FEATURE
# SW_IN_T1_47_1_gfXG     1.022059  1.022059  0.816129  0.910954  0.577234  0.727780  0.903731  1.375449  1.375449
# .DOY_COS               0.269020  0.269020  0.526971  0.475984  0.181065  0.147509  0.210092  0.366898  0.366898
# .HOUR_COS              0.225138  0.225138  0.239092  0.227079  0.204208  0.209163  0.213397  0.278173  0.278173
# .WEEK_COS              0.112484  0.112484  0.004729  0.009703  0.045888  0.078259  0.038506  0.009247  0.009247
# .VPD_T1_47_1_gfXG-1    0.091566  0.091566  0.117250  0.118370  0.093826  0.095001  0.092799  0.098290  0.098290
# VPD_T1_47_1_gfXG       0.080280  0.080280  0.061668  0.047330  0.040257  0.051622  0.073290  0.048733  0.048733
# .DOY_SIN               0.071196  0.071196  0.095112  0.046921  0.031210  0.033398  0.039737  0.046944  0.046944
# .SW_IN_T1_47_1_gfXG-1  0.063345  0.063345  0.098214  0.122052  0.147520  0.137611  0.145352  0.138805  0.138805
# .RECORDNUMBER          0.053929  0.053929  0.058641  0.054200  0.057569  0.044522  0.118245  0.030014  0.030014
# .TA_T1_47_1_gfXG-1     0.050245  0.050245  0.047876  0.036383  0.040289  0.082480  0.057981  0.038065  0.038065
# TA_T1_47_1_gfXG        0.036085  0.036085  0.029542  0.031627  0.039837  0.063662  0.030480  0.030021  0.030021
# .HOUR_SIN              0.029783  0.029783  0.027889  0.026308  0.021515  0.032618  0.038680  0.036928  0.036928
# .YEARDOY               0.015598  0.015598  0.020641  0.013424  0.014931  0.015048  0.019325  0.010847  0.010847
# .WEEK_SIN              0.006906  0.006906  0.006902  0.038615  0.021287  0.019423  0.005556  0.004939  0.004939
# .YEARWEEK              0.004272  0.004272  0.004699  0.004720  0.005858  0.004839  0.004647  0.003955  0.003955
# .MONTH_COS             0.002547  0.002547  0.002144  0.002909  0.002465  0.003332  0.003775  0.002564  0.002564
# .YEARMONTH             0.001614  0.001614  0.001830  0.001815  0.002232  0.002430  0.002021  0.001710  0.001710
# .SEASON_COS            0.001155  0.001155  0.000754  0.000684  0.054297  0.005058  0.005616  0.001079  0.001079
# .MONTH_SIN             0.001006  0.001006  0.006915  0.001049  0.042177  0.055696  0.169873  0.076169  0.076169
# .YEAR                  0.000551  0.000551  0.000646  0.000598  0.001142  0.000923  0.000521  0.000528  0.000528
# .SEASON_SIN            0.000235  0.000235  0.000228  0.000282  0.000352  0.000240  0.000269  0.000208  0.000208

# %% [markdown]
# ## Names of gap-filled variables

# %%
print("Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:")
fpc.report_gapfilling_variables()
# Out:
# Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:
# long_term_random_forest (CUT_16): NEE_L3.1_L3.3_CUT_16_QCF -> NEE_L3.1_L3.3_CUT_16_QCF_gfRF
# long_term_random_forest (CUT_50): NEE_L3.1_L3.3_CUT_50_QCF -> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# long_term_random_forest (CUT_84): NEE_L3.1_L3.3_CUT_84_QCF -> NEE_L3.1_L3.3_CUT_84_QCF_gfRF

# %%
gapfilled_names = fpc.get_gapfilled_names()
gapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_16_QCF_gfRF',
#  'NEE_L3.1_L3.3_CUT_50_QCF_gfRF',
#  'NEE_L3.1_L3.3_CUT_84_QCF_gfRF']

# %% [markdown]
# Gap-filled data can also be accessed directly. To get all gap-filled variables and also the same variables before gap-filling in a dataframe, use `.get_gapfilled_variables()`:

# %%
gapfilled_vars = fpc.get_gapfilled_variables()
gapfilled_vars.head(3)
# Out:
#                      NEE_L3.1_L3.3_CUT_16_QCF_gfRF  NEE_L3.1_L3.3_CUT_50_QCF_gfRF  NEE_L3.1_L3.3_CUT_84_QCF_gfRF  NEE_L3.1_L3.3_CUT_16_QCF  NEE_L3.1_L3.3_CUT_50_QCF  NEE_L3.1_L3.3_CUT_84_QCF
# TIMESTAMP_MIDDLE
# 2016-01-01 00:15:00                       3.820397                       3.144036                       3.039052                       NaN                       NaN                       NaN
# 2016-01-01 00:45:00                       3.820397                       3.144036                       3.039052                       NaN                       NaN                       NaN
# 2016-01-01 01:15:00                       4.519701                       3.751522                       3.541547                       NaN                       NaN                       NaN

# %% [markdown]
# The names of the flux that was gap-filled can be accessed like this:

# %%
nongapfilled_names = fpc.get_nongapfilled_names()
nongapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_16_QCF',
#  'NEE_L3.1_L3.3_CUT_50_QCF',
#  'NEE_L3.1_L3.3_CUT_84_QCF']

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Heatmaps

# %%
fpc.showplot_gapfilled_heatmap()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py:502: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py:502: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py:502: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Cumulatives per year

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=True)
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:145: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:145: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:145: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# ### Cumulative across all data

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=False)
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:251: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# ### ML Feature ranks per year (machine learning models only)

# %%
fpc.showplot_feature_ranks_per_year()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:268: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(row.index, row.values, "o", marker=verts, ms=20,
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:287: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### MDS gap-filling qualities (MDS only, otherwise skipped)

# %%
fpc.showplot_mds_gapfilling_qualities()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # SAVE RESULTS TO FILE

# %% [markdown]
# - Save results to file for futher processing
# - This can be useful if you want to use the data in another software, e.g. continuing post-processing using the library `ReddyProc` in `R`
# - `Parquet` format is recommended for large datasets

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Save complete data (input data and results) to CSV (large and slow)

# %%
# results.to_csv("FluxProcessingChain_L4.1.csv")

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Save input data and results to Parquet (small and fast)
# - Needed if you want to continue post-processing in notebooks
# - Can also be used in `R` with the `arrow` package

# %%
save_parquet(data=results, filename="04_FPC_IRGA72_NEE-QCF10-UST165084-L4.1-RF")
# Out:
# Saved file 04_FPC_IRGA72_NEE-QCF10-UST165084-L4.1-RF.parquet (3.249 seconds).
# '04_FPC_IRGA72_NEE-QCF10-UST165084-L4.1-RF.parquet'

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # ✅END OF NOTEBOOK

# %% [markdown]
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2025-12-02 14:23:06
