# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Flux Processing Chain (here starting Level-4.1)
# </b>
# </br>
#
# </span>
# <p>Post-processing of EddyPro <i>_fluxnet_</i> output files</p>

# %% [markdown]
# ---
# **Notebook version**: `11.0` (19 Nov 2025)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %%
import pickle
from datetime import datetime
from diive.core.io.files import save_parquet, load_parquet

# %% [markdown]
# </br>

# %% [markdown]
# # Load previous `fpc` instance

# %%
# 1. Load the instance from the pickle file
file_path = '02_fpcInstance_IRGA72_NEE-QCF11-UST50-L3.3.pkl'
with open(file_path, 'rb') as file:
    fpc = pickle.load(file)

# %%
fpc

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🟢Level-4.1: GAP-FILLING

# %% [markdown]
# - Introduced in `diive` v0.85.0, gap-filling can now be done using both random forest and MDS
# - For gap-filling using MDS, make sure that variables are in the required units: short-wave incoming radiation in `W m-2`, air temperature in `°C`, VPD in `hPa`
#
# Parameters:
# - `mds_settings` are parameters for the MDS gap-filling method, [see docstring here for more details](https://github.com/holukas/diive/blob/main/diive/pkgs/gapfilling/mds.py)
# - `rf_settings` are parameters for scikit's `RandomForestRegressor` model, [see their official documentation for allowed parameters](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# - `ml_feature_settings` are general settings for machine-learning models (such as random forest)

# %% [markdown]
# ## 🔸Long-term random forest

# %%
FEATURES = ["TA_T1_47_1_gfXG", "SW_IN_T1_47_1_gfXG", "VPD_T1_47_1_gfXG"]
fpc.level41_longterm_random_forest(
    features=FEATURES,
    sanitize_timestamp=True,
    features_lag=[-1, -1],
    features_lag_stepsize=1,
    features_lag_exclude_cols=None,
    reduce_features=False,
    vectorize_timestamps=True,
    add_continuous_record_number=True,
    perm_n_repeats=10,
    verbose=True,
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    n_jobs=1,
    random_state=42,
)
# Out:
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Adding new data columns ...
# ++ Added new columns with lagged variants for: ['TA_T1_47_1_gfXG', 'SW_IN_T1_47_1_gfXG', 'VPD_T1_47_1_gfXG'] (lags between -1 and -1 with stepsize 1), no lagged variants for: ['NEE_L3.1_L3.3_CUT_50_QCF']. Shifting the time series created gaps which were then filled with the nearest value.
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
# ++ Added new column .RECORDNUMBER with record numbers from 1 to 157824.
#
# Sanitizing timestamp ...
# >>> Validating timestamp naming of timestamp column TIMESTAMP_MIDDLE ... Timestamp name OK.
# >>> Converting timestamp TIMESTAMP_MIDDLE to datetime ... OK
# >>> All rows have timestamp TIMESTAMP_MIDDLE, no rows removed.
# >>> Sorting timestamp TIMESTAMP_MIDDLE ascending ...
# >>> Removing data records with duplicate indexes ... OK (no duplicates found in timestamp index)
# >>> Creating continuous <30 * Minutes> timestamp index for timestamp TIMESTAMP_MIDDLE between 2016-01-01 00:15:00 and 2024-12-31 23:45:00 ...
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2018, 2019, 2020] to data pool for 2019.
# [neighboring_years] Assigned [2019, 2020, 2021] to data pool for 2020.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2021.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2022.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2023.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2024.
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2020 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2021 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2022 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2023 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2024 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Training model for 2016 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 12:45:00 and 2018-12-31 01:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2016 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 32184 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2017 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 12:45:00 and 2018-12-31 01:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2017 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 32184 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2018 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 09:15:00 and 2019-12-31 02:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2018 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 31437 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2019 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2018-01-09 11:15:00 and 2020-12-17 13:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2019 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 31521 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2020 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2019-01-01 09:45:00 and 2021-12-13 12:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2020 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 31651 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2021 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2020-01-02 05:15:00 and 2022-12-31 21:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2021 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 30515 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2022 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2021-01-04 16:45:00 and 2023-12-31 23:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2022 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 29921 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2023 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 11:15:00 and 2024-12-31 18:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2023 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 29377 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2024 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 11:15:00 and 2024-12-31 18:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2024 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 29377 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2016 ...
# Collecting results for 2017 ...
# Collecting results for 2018 ...
# Collecting results for 2019 ...
# Collecting results for 2020 ...
# Collecting results for 2021 ...
# Collecting results for 2022 ...
# Collecting results for 2023 ...
# Collecting results for 2024 ...

# %% [markdown]
# ## 🔸MDS (Marginal Distribution Sampling)

# %%
# fpc.level41_mds(
#     swin="SW_IN_T1_47_1_gfXG",
#     ta="TA_T1_47_1_gfXG",
#     vpd="VPD_T1_47_1_gfXG",
#     swin_tol=[20, 50],
#     ta_tol=2.5,
#     vpd_tol=0.5,
#     avg_min_n_vals=5
# )

# %% [markdown]
# ## Get results
# - Results from the flux processing chain can be accessed using `.get_data()`
# - This returns a dataframe containing all input data and all newly generated variables, such as quality flags, quality-filtered fluxes and gap-filled fluxes

# %%
results = fpc.get_data(verbose=1)
results
# Out:
# NEW VARIABLES FROM FLUX PROCESSING CHAIN:
# ++ FLAG_L2_FC_MISSING_TEST
# ++ FLAG_L2_FC_SSITC_TEST
# ++ FLAG_L2_FC_SCF_TEST
# ++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST
# ++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST
# ++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST
# ++ SUM_L2_FC_HARDFLAGS
# ++ SUM_L2_FC_SOFTFLAGS
# ++ SUM_L2_FC_FLAGS
# ++ FLAG_L2_FC_QCF
# ++ FC_L2_QCF
# ++ FC_L2_QCF0
# ++ SC_SINGLE_gfRMED_L3.1
# ++ FLAG_SC_SINGLE_gfRMED_L3.1_ISFILLED
# ++ NEE_L3.1
# ++ NEE_L3.1_QCF
# ++ NEE_L3.1_QCF0
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_TEST
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_MANUAL_TEST
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_ABSLIM_DTNT_TEST
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_LOCALSD_TEST
# ++ SUM_L3.2_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.2_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.2_NEE_L3.1_FLAGS
# ++ FLAG_L3.2_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.2_QCF
# ++ NEE_L3.1_L3.2_QCF0
# ++ FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_50_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_50_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_50_NEE_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_50_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.3_CUT_50_QCF
# ++ NEE_L3.1_L3.3_CUT_50_QCF0
# ++ NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# ++ FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfRF_ISFILLED
# No variables in input data were overwritten, only new variables added.
#                       AIR_CP  AIR_DENSITY    AIR_MV  AIR_RHO_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  SUM_L3.3_CUT_50_NEE_L3.1_FLAGS  FLAG_L3.3_CUT_50_NEE_L3.1_QCF  NEE_L3.1_L3.3_CUT_50_QCF  NEE_L3.1_L3.3_CUT_50_QCF0  NEE_L3.1_L3.3_CUT_50_QCF_gfRF  FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfRF_ISFILLED
# TIMESTAMP_MIDDLE                                                                                   ...
# 2016-01-01 00:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       4.272090                                            1
# 2016-01-01 00:45:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       4.272090                                            1
# 2016-01-01 01:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       4.881520                                            1
# 2016-01-01 01:45:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       4.585795                                            1
# 2016-01-01 02:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                             2.0                            2.0                       NaN                        NaN                       4.285732                                            1
# ...                      ...          ...       ...         ...         ...                   ...  ...                             ...                            ...                       ...                        ...                            ...                                          ...
# 2024-12-31 21:45:00  1008.09      1.20135  0.024060     1211.07         0.0                   1.0  ...                             3.0                            2.0                       NaN                        NaN                       2.340607                                            1
# 2024-12-31 22:15:00  1008.14      1.20010  0.024085     1209.87         0.0                   1.0  ...                             2.0                            2.0                       NaN                        NaN                       1.395871                                            1
# 2024-12-31 22:45:00  1008.20      1.20023  0.024081     1210.07         0.0                   1.0  ...                             3.0                            2.0                       NaN                        NaN                       1.532097                                            1
# 2024-12-31 23:15:00  1008.19      1.19504  0.024186     1204.83         0.0                   1.0  ...                             3.0                            2.0                       NaN                        NaN                       1.138062                                            1
# 2024-12-31 23:45:00  1008.15      1.20042  0.024078     1210.20         0.0                   1.0  ...                             2.0                            2.0                       NaN                        NaN                       2.632115                                            1
#
# [157824 rows x 381 columns]

# %% [markdown]
# ## Model scores

# %% [markdown]
# ### Model scores and details on test data

# %%
# Show train/test details
print(fpc.report_traintest_model_scores())
print(fpc.report_traintest_details())
# fpc.report_traintest_model_scores(outpath=".")  # Save in current folder
# fpc.report_traintest_details(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES from TRAINING/TESTING (long_term_random_forest):
#  trained on training data, tested on unseen test data CUT_50
#             2016       2017       2018       2019       2020       2021       2022       2023       2024
# mae     3.283234   3.283234   3.292117   3.332961   3.373282   3.203736   3.040627   3.009197   3.009197
# medae   2.005949   2.005949   1.994921   2.028507   1.948221   1.827493   1.795201   1.813713   1.813713
# mse    26.363323  26.363323  26.544357  26.530565  28.432224  27.023180  23.319679  22.779641  22.779641
# rmse    5.134523   5.134523   5.152122   5.150783   5.332188   5.198382   4.829045   4.772802   4.772802
# mape    2.105210   2.105210   3.660868   3.167821   1.631180   1.713828   2.071314   2.104417   2.104417
# maxe   42.339498  42.339498  48.083001  46.715931  43.772020  44.776245  39.623127  55.805184  55.805184
# r2      0.731418   0.731418   0.731405   0.738289   0.732048   0.725751   0.755980   0.765127   0.765127
# None
#
# DETAILS from TRAINING/TESTING (long_term_random_forest CUT_50):
#  trained on training data, tested on unseen test data
#                                                         2016                                               2017                                               2018                                               2019                                               2020                                               2021                                               2022                                               2023                                               2024
# train_df                        TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_df                         TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_size                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25
# X_names    [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...
# model      (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...
# None

# %% [markdown]
# ### Model scores on all data

# %%
fpc.report_gapfilling_model_scores()
# fpc.report_gapfilling_model_scores(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES (long_term_random_forest): CUT_50
#             2016       2017       2018       2019       2020       2021       2022       2023       2024
# mae     1.722785   1.722785   1.750009   1.742238   1.769157   1.678081   1.634623   1.599531   1.599531
# medae   0.912443   0.912443   0.927381   0.900449   0.894511   0.838836   0.846985   0.838310   0.838310
# mse     9.225567   9.225567   9.403976   9.343563  10.046146   9.373683   8.460344   8.081477   8.081477
# rmse    3.037362   3.037362   3.066590   3.056724   3.169566   3.061647   2.908667   2.842794   2.842794
# mape    1.236546   1.236546   1.490047   1.366033   1.267172   1.017550   1.080378   1.154536   1.154536
# maxe   42.339498  42.339498  48.083001  46.715931  43.772020  44.776245  39.623127  55.805184  55.805184
# r2      0.907301   0.907301   0.905033   0.907405   0.906263   0.903863   0.911718   0.917304   0.917304

# %% [markdown]
# During long-term gap-filling, different years are pooled together to predict one central year, i.e., multiple models are used.
# The used data pools can be display with:

# %%
fpc.report_gapfilling_poolyears()
# Out:
# DATA POOLS USED FOR MACHINE-LEARNING GAP-FILLING:
# 2016: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2017: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2018: long_term_random_forest used data from [2017, 2018, 2019] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2019: long_term_random_forest used data from [2018, 2019, 2020] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2020: long_term_random_forest used data from [2019, 2020, 2021] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2021: long_term_random_forest used data from [2020, 2021, 2022] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2022: long_term_random_forest used data from [2021, 2022, 2023] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2023: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2024: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF

# %%
fpc.report_gapfilling_feature_importances()  # Save in current folder
# fpc.report_gapfilling_feature_importances(outpath=".")  # Save in current folder
# Out:
# FEATURE IMPORTANCES (long_term_random_forest): CUT_50
# YEAR                       2016      2017      2018      2019      2020      2021      2022      2023      2024
# FEATURE
# SW_IN_T1_47_1_gfXG     0.939564  0.939564  0.850974  0.997952  0.987335  0.900828  0.618294  1.575617  1.575617
# .DOY_COS               0.327373  0.327373  0.587876  0.499973  0.156234  0.151670  0.185729  0.386360  0.386360
# .HOUR_COS              0.281505  0.281505  0.334166  0.290637  0.183237  0.290322  0.195986  0.273463  0.273463
# .VPD_T1_47_1_gfXG-1    0.112262  0.112262  0.109941  0.097777  0.094568  0.104329  0.148071  0.121941  0.121941
# .WEEK_COS              0.105762  0.105762  0.004526  0.005602  0.043591  0.115035  0.022095  0.010506  0.010506
# .SW_IN_T1_47_1_gfXG-1  0.090049  0.090049  0.076439  0.113664  0.114046  0.106068  0.197358  0.165133  0.165133
# VPD_T1_47_1_gfXG       0.084341  0.084341  0.064756  0.051385  0.041991  0.056511  0.099544  0.060316  0.060316
# .DOY_SIN               0.081748  0.081748  0.089523  0.072122  0.035475  0.032050  0.036985  0.043687  0.043687
# .RECORDNUMBER          0.052750  0.052750  0.069534  0.059694  0.057978  0.046547  0.120044  0.031670  0.031670
# .TA_T1_47_1_gfXG-1     0.038418  0.038418  0.039920  0.039169  0.040771  0.045846  0.059657  0.042567  0.042567
# TA_T1_47_1_gfXG        0.036735  0.036735  0.033083  0.032944  0.041116  0.072266  0.042173  0.033460  0.033460
# .HOUR_SIN              0.027522  0.027522  0.030274  0.024680  0.024509  0.028183  0.035017  0.044541  0.044541
# .YEARDOY               0.014898  0.014898  0.016056  0.014617  0.016256  0.015369  0.019883  0.011433  0.011433
# .WEEK_SIN              0.005040  0.005040  0.005789  0.012564  0.022295  0.033134  0.005652  0.004922  0.004922
# .YEARWEEK              0.004059  0.004059  0.004601  0.004508  0.004450  0.004901  0.004329  0.004433  0.004433
# .MONTH_COS             0.003163  0.003163  0.004349  0.003772  0.002490  0.002235  0.003298  0.002197  0.002197
# .YEARMONTH             0.001466  0.001466  0.001782  0.001975  0.002036  0.002174  0.001995  0.001932  0.001932
# .MONTH_SIN             0.000923  0.000923  0.003008  0.001172  0.070718  0.036256  0.154616  0.089860  0.089860
# .SEASON_COS            0.000877  0.000877  0.000565  0.000610  0.032858  0.003565  0.008434  0.001424  0.001424
# .YEAR                  0.000608  0.000608  0.000807  0.000670  0.000941  0.000878  0.000611  0.000654  0.000654
# .SEASON_SIN            0.000247  0.000247  0.000246  0.000254  0.000385  0.000247  0.000221  0.000178  0.000178

# %% [markdown]
# ## Names of gap-filled variables

# %%
print("Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:")
fpc.report_gapfilling_variables()
# Out:
# Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:
# long_term_random_forest (CUT_50): NEE_L3.1_L3.3_CUT_50_QCF -> NEE_L3.1_L3.3_CUT_50_QCF_gfRF

# %%
gapfilled_names = fpc.get_gapfilled_names()
gapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF_gfRF']

# %% [markdown]
# Gap-filled data can also be accessed directly. To get all gap-filled variables and also the same variables before gap-filling in a dataframe, use `.get_gapfilled_variables()`:

# %%
gapfilled_vars = fpc.get_gapfilled_variables()
gapfilled_vars.head(3)
# Out:
#                      NEE_L3.1_L3.3_CUT_50_QCF_gfRF  NEE_L3.1_L3.3_CUT_50_QCF
# TIMESTAMP_MIDDLE
# 2016-01-01 00:15:00                        4.27209                       NaN
# 2016-01-01 00:45:00                        4.27209                       NaN
# 2016-01-01 01:15:00                        4.88152                       NaN

# %% [markdown]
# The names of the flux that was gap-filled can be accessed like this:

# %%
nongapfilled_names = fpc.get_nongapfilled_names()
nongapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF']

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Heatmaps

# %%
fpc.showplot_gapfilled_heatmap()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py:502: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Cumulatives per year

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=True)
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:145: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# ### Cumulative across all data

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=False)
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:251: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# ### ML Feature ranks per year (machine learning models only)

# %%
fpc.showplot_feature_ranks_per_year()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:268: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(row.index, row.values, "o", marker=verts, ms=20,
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:287: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### MDS gap-filling qualities (MDS only, otherwise skipped)

# %%
fpc.showplot_mds_gapfilling_qualities()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # SAVE RESULTS TO FILE

# %% [markdown]
# - Save results to file for futher processing
# - This can be useful if you want to use the data in another software, e.g. continuing post-processing using the library `ReddyProc` in `R`
# - `Parquet` format is recommended for large datasets

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Save complete data (input data and results) to CSV (large and slow)

# %%
# results.to_csv("FluxProcessingChain_L4.1.csv")

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Save input data and results to Parquet (small and fast)
# - Needed if you want to continue post-processing in notebooks
# - Can also be used in `R` with the `arrow` package

# %%
# save_parquet(data=results, filename="04_FPC_IRGA72_NEE-QCF10-UST165084-L4.1-RF")

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # ✅END OF NOTEBOOK

# %% [markdown]
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2025-12-03 23:59:41
