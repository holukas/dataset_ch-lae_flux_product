# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Flux Processing Chain (here starting Level-4.1)
# </b>
# </br>
#
# </span>
# <p>Post-processing of EddyPro <i>_fluxnet_</i> output files</p>

# %% [markdown]
# ---
# **Notebook version**: `11.0` (19 Nov 2025)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %%
import pickle
from datetime import datetime
from diive.core.io.files import save_parquet, load_parquet

# %% [markdown]
# </br>

# %% [markdown]
# # Load previous `fpc` instance

# %%
# 1. Load the instance from the pickle file
file_path = '12_fpcInstance_IRGA72_LE-QCF11-USTNONE-L3.3.pkl'
with open(file_path, 'rb') as file:
    fpc = pickle.load(file)

# %%
fpc

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🟢Level-4.1: GAP-FILLING

# %% [markdown]
# - Introduced in `diive` v0.85.0, gap-filling can now be done using both random forest and MDS
# - For gap-filling using MDS, make sure that variables are in the required units: short-wave incoming radiation in `W m-2`, air temperature in `°C`, VPD in `hPa`
#
# Parameters:
# - `mds_settings` are parameters for the MDS gap-filling method, [see docstring here for more details](https://github.com/holukas/diive/blob/main/diive/pkgs/gapfilling/mds.py)
# - `rf_settings` are parameters for scikit's `RandomForestRegressor` model, [see their official documentation for allowed parameters](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# - `ml_feature_settings` are general settings for machine-learning models (such as random forest)

# %% [markdown]
# ## 🔸Long-term random forest

# %%
FEATURES = ["TA_T1_47_1_gfXG", "SW_IN_T1_47_1_gfXG", "VPD_T1_47_1_gfXG"]
fpc.level41_longterm_random_forest(
    features=FEATURES,
    sanitize_timestamp=True,
    features_lag=[-1, -1],
    features_lag_stepsize=1,
    features_lag_exclude_cols=None,
    reduce_features=False,
    vectorize_timestamps=True,
    add_continuous_record_number=True,
    perm_n_repeats=10,
    verbose=True,
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    n_jobs=1,
    random_state=42,
)
# Out:
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Adding new data columns ...
# ++ Added new columns with lagged variants for: ['TA_T1_47_1_gfXG', 'SW_IN_T1_47_1_gfXG', 'VPD_T1_47_1_gfXG'] (lags between -1 and -1 with stepsize 1), no lagged variants for: ['LE_L3.1_L3.3_NONE_QCF']. Shifting the time series created gaps which were then filled with the nearest value.
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
# ++ Added new column .RECORDNUMBER with record numbers from 1 to 157824.
#
# Sanitizing timestamp ...
# >>> Validating timestamp naming of timestamp column TIMESTAMP_MIDDLE ... Timestamp name OK.
# >>> Converting timestamp TIMESTAMP_MIDDLE to datetime ... OK
# >>> All rows have timestamp TIMESTAMP_MIDDLE, no rows removed.
# >>> Sorting timestamp TIMESTAMP_MIDDLE ascending ...
# >>> Removing data records with duplicate indexes ... OK (no duplicates found in timestamp index)
# >>> Creating continuous <30 * Minutes> timestamp index for timestamp TIMESTAMP_MIDDLE between 2016-01-01 00:15:00 and 2024-12-31 23:45:00 ...
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2018, 2019, 2020] to data pool for 2019.
# [neighboring_years] Assigned [2019, 2020, 2021] to data pool for 2020.
# [neighboring_years] Assigned [2020, 2021, 2022] to data pool for 2021.
# [neighboring_years] Assigned [2021, 2022, 2023] to data pool for 2022.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2023.
# [neighboring_years] Assigned [2022, 2023, 2024] to data pool for 2024.
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2020 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2021 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2022 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2023 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2024 ...
#
#
# ============================================================
# Starting gap-filling for
# LE_L3.1_L3.3_NONE_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Training model for 2016 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 00:15:00 and 2018-12-31 23:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2016 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 22189 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2017 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-22 00:15:00 and 2018-12-31 23:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2017 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 22189 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2018 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 00:15:00 and 2019-12-31 21:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2018 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 20867 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2019 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2018-01-02 21:15:00 and 2020-12-18 15:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2019 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 20892 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2020 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2019-01-01 01:45:00 and 2021-12-13 18:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2020 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 20574 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2021 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2020-01-01 00:45:00 and 2022-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2021 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 19477 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2022 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2021-01-04 18:15:00 and 2023-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2022 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 18585 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2023 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 11:45:00 and 2024-12-31 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2023 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 18257 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2024 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2022-02-07 11:45:00 and 2024-12-31 22:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target LE_L3.1_L3.3_NONE_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of LE_L3.1_L3.3_NONE_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2024 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target LE_L3.1_L3.3_NONE_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting LE_L3.1_L3.3_NONE_QCF ...
# >>> Predicting target LE_L3.1_L3.3_NONE_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 18257 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable LE_L3.1_L3.3_NONE_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in LE_L3.1_L3.3_NONE_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2016 ...
# Collecting results for 2017 ...
# Collecting results for 2018 ...
# Collecting results for 2019 ...
# Collecting results for 2020 ...
# Collecting results for 2021 ...
# Collecting results for 2022 ...
# Collecting results for 2023 ...
# Collecting results for 2024 ...

# %% [markdown]
# ## 🔸MDS (Marginal Distribution Sampling)

# %%
# fpc.level41_mds(
#     swin="SW_IN_T1_47_1_gfXG",
#     ta="TA_T1_47_1_gfXG",
#     vpd="VPD_T1_47_1_gfXG",
#     swin_tol=[20, 50],
#     ta_tol=2.5,
#     vpd_tol=0.5,
#     avg_min_n_vals=5
# )

# %% [markdown]
# ## Get results
# - Results from the flux processing chain can be accessed using `.get_data()`
# - This returns a dataframe containing all input data and all newly generated variables, such as quality flags, quality-filtered fluxes and gap-filled fluxes

# %%
results = fpc.get_data(verbose=1)
results
# Out:
# NEW VARIABLES FROM FLUX PROCESSING CHAIN:
# ++ FLAG_L2_LE_MISSING_TEST
# ++ FLAG_L2_LE_SSITC_TEST
# ++ FLAG_L2_LE_SCF_TEST
# ++ FLAG_L2_LE_SIGNAL_STRENGTH_TEST
# ++ FLAG_L2_LE_H2O_VM97_SPIKE_HF_TEST
# ++ FLAG_L2_LE_H2O_VM97_DROPOUT_TEST
# ++ SUM_L2_LE_HARDFLAGS
# ++ SUM_L2_LE_SOFTFLAGS
# ++ SUM_L2_LE_FLAGS
# ++ FLAG_L2_LE_QCF
# ++ LE_L2_QCF
# ++ LE_L2_QCF0
# ++ SLE_SINGLE_gfRMED_L3.1
# ++ FLAG_SLE_SINGLE_gfRMED_L3.1_ISFILLED
# ++ LE_L3.1
# ++ LE_L3.1_QCF
# ++ LE_L3.1_QCF0
# ++ FLAG_L3.2_LE_L3.1_QCF_OUTLIER_ABSLIM_TEST
# ++ FLAG_L3.2_LE_L3.1_QCF_OUTLIER_MANUAL_TEST
# ++ FLAG_L3.2_LE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST
# ++ SUM_L3.2_LE_L3.1_HARDFLAGS
# ++ SUM_L3.2_LE_L3.1_SOFTFLAGS
# ++ SUM_L3.2_LE_L3.1_FLAGS
# ++ FLAG_L3.2_LE_L3.1_QCF
# ++ LE_L3.1_L3.2_QCF
# ++ LE_L3.1_L3.2_QCF0
# ++ FLAG_L3.3_NONE_LE_L3.1_USTAR_TEST
# ++ SUM_L3.3_NONE_LE_L3.1_HARDFLAGS
# ++ SUM_L3.3_NONE_LE_L3.1_SOFTFLAGS
# ++ SUM_L3.3_NONE_LE_L3.1_FLAGS
# ++ FLAG_L3.3_NONE_LE_L3.1_QCF
# ++ LE_L3.1_L3.3_NONE_QCF
# ++ LE_L3.1_L3.3_NONE_QCF0
# ++ LE_L3.1_L3.3_NONE_QCF_gfRF
# ++ FLAG_LE_L3.1_L3.3_NONE_QCF_gfRF_ISFILLED
# No variables in input data were overwritten, only new variables added.
#                       AIR_CP  AIR_DENSITY    AIR_MV  AIR_RHO_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  SUM_L3.3_NONE_LE_L3.1_FLAGS  FLAG_L3.3_NONE_LE_L3.1_QCF  LE_L3.1_L3.3_NONE_QCF  LE_L3.1_L3.3_NONE_QCF0  LE_L3.1_L3.3_NONE_QCF_gfRF  FLAG_LE_L3.1_L3.3_NONE_QCF_gfRF_ISFILLED
# TIMESTAMP_MIDDLE                                                                                   ...
# 2016-01-01 00:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                          2.0                         2.0                    NaN                     NaN                   -1.583467                                         1
# 2016-01-01 00:45:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                          2.0                         2.0                    NaN                     NaN                   -1.583467                                         1
# 2016-01-01 01:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                          2.0                         2.0                    NaN                     NaN                   -1.011555                                         1
# 2016-01-01 01:45:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                          2.0                         2.0                    NaN                     NaN                   -1.277127                                         1
# 2016-01-01 02:15:00      NaN          NaN       NaN         NaN         NaN                   NaN  ...                          2.0                         2.0                    NaN                     NaN                   -1.932661                                         1
# ...                      ...          ...       ...         ...         ...                   ...  ...                          ...                         ...                    ...                     ...                         ...                                       ...
# 2024-12-31 21:45:00  1008.09      1.20135  0.024060     1211.07         0.0                   1.0  ...                          2.0                         2.0                    NaN                     NaN                    6.406184                                         1
# 2024-12-31 22:15:00  1008.14      1.20010  0.024085     1209.87         0.0                   1.0  ...                          1.0                         1.0                2.28642                     NaN                    2.286420                                         0
# 2024-12-31 22:45:00  1008.20      1.20023  0.024081     1210.07         0.0                   1.0  ...                          2.0                         2.0                    NaN                     NaN                    1.114409                                         1
# 2024-12-31 23:15:00  1008.19      1.19504  0.024186     1204.83         0.0                   1.0  ...                          2.0                         2.0                    NaN                     NaN                    3.128624                                         1
# 2024-12-31 23:45:00  1008.15      1.20042  0.024078     1210.20         0.0                   1.0  ...                          2.0                         2.0                    NaN                     NaN                    6.078937                                         1
#
# [157824 rows x 379 columns]

# %% [markdown]
# ## Model scores

# %% [markdown]
# ### Model scores and details on test data

# %%
# Show train/test details
print(fpc.report_traintest_model_scores())
print(fpc.report_traintest_details())
# fpc.report_traintest_model_scores(outpath=".")  # Save in current folder
# fpc.report_traintest_details(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES from TRAINING/TESTING (long_term_random_forest):
#  trained on training data, tested on unseen test data NONE
#               2016         2017         2018         2019         2020         2021         2022         2023         2024
# mae      28.313096    28.313096    29.346596    28.264816    27.396793    27.426275    26.979228    28.258384    28.258384
# medae    12.781396    12.781396    13.458286    13.255907    12.575833    12.206239    12.369330    12.361628    12.361628
# mse    2635.486308  2635.486308  2804.955126  2613.727989  2480.559980  2522.941346  2366.117570  2697.448471  2697.448471
# rmse     51.336988    51.336988    52.961827    51.124632    49.805220    50.228890    48.642755    51.936966    51.936966
# mape      2.167375     2.167375     4.519377     5.868797     6.851002     2.174241     2.781568     3.237888     3.237888
# maxe    467.910499   467.910499   576.274518   663.166035   557.340433   573.507563   492.052187   536.889121   536.889121
# r2        0.780811     0.780811     0.764972     0.768806     0.785151     0.774321     0.790388     0.775502     0.775502
# None
#
# DETAILS from TRAINING/TESTING (long_term_random_forest NONE):
#  trained on training data, tested on unseen test data
#                                                         2016                                               2017                                               2018                                               2019                                               2020                                               2021                                               2022                                               2023                                               2024
# train_df                        TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_df                         TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_size                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25
# X_names    [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...
# model      (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...
# None

# %% [markdown]
# ### Model scores on all data

# %%
fpc.report_gapfilling_model_scores()
# fpc.report_gapfilling_model_scores(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES (long_term_random_forest): NONE
#              2016        2017        2018        2019        2020        2021        2022        2023        2024
# mae     14.771160   14.771160   15.149758   14.668355   14.420656   14.459633   14.335379   14.815935   14.815935
# medae    5.769819    5.769819    6.126884    6.140820    5.820601    5.762678    5.544260    5.751360    5.751360
# mse    913.565119  913.565119  961.662886  894.221499  873.337307  883.756815  854.269743  940.190981  940.190981
# rmse    30.225240   30.225240   31.010690   29.903537   29.552281   29.728048   29.227893   30.662534   30.662534
# mape     1.300470    1.300470    2.405483    2.657032    2.868674    1.286585    1.585483    1.760617    1.760617
# maxe   467.910499  467.910499  576.274518  663.166035  557.340433  573.507563  492.052187  536.889121  536.889121
# r2       0.924094    0.924094    0.917765    0.917454    0.924927    0.918945    0.923233    0.920377    0.920377

# %% [markdown]
# During long-term gap-filling, different years are pooled together to predict one central year, i.e., multiple models are used.
# The used data pools can be display with:

# %%
fpc.report_gapfilling_poolyears()
# Out:
# DATA POOLS USED FOR MACHINE-LEARNING GAP-FILLING:
# 2016: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF
# 2017: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF
# 2018: long_term_random_forest used data from [2017, 2018, 2019] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF
# 2019: long_term_random_forest used data from [2018, 2019, 2020] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF
# 2020: long_term_random_forest used data from [2019, 2020, 2021] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF
# 2021: long_term_random_forest used data from [2020, 2021, 2022] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF
# 2022: long_term_random_forest used data from [2021, 2022, 2023] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF
# 2023: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF
# 2024: long_term_random_forest used data from [2022, 2023, 2024] for gap-filling LE_L3.1_L3.3_NONE_QCF and producing --> LE_L3.1_L3.3_NONE_QCF_gfRF

# %%
fpc.report_gapfilling_feature_importances()  # Save in current folder
# fpc.report_gapfilling_feature_importances(outpath=".")  # Save in current folder
# Out:
# FEATURE IMPORTANCES (long_term_random_forest): NONE
# YEAR                       2016      2017      2018      2019      2020      2021      2022      2023      2024
# FEATURE
# SW_IN_T1_47_1_gfXG     0.851053  0.851053  1.076059  0.829950  0.956296  0.958968  0.820305  0.874820  0.874820
# .SW_IN_T1_47_1_gfXG-1  0.099473  0.099473  0.097984  0.264278  0.074285  0.130073  0.132973  0.170193  0.170193
# .DOY_COS               0.096161  0.096161  0.045288  0.086817  0.045626  0.038749  0.037811  0.063860  0.063860
# TA_T1_47_1_gfXG        0.063934  0.063934  0.081130  0.096333  0.112601  0.202234  0.185092  0.096185  0.096185
# .WEEK_COS              0.063350  0.063350  0.003192  0.003471  0.005772  0.007988  0.005402  0.004953  0.004953
# .RECORDNUMBER          0.056103  0.056103  0.058140  0.057281  0.043527  0.070943  0.090274  0.104006  0.104006
# .DOY_SIN               0.048015  0.048015  0.037679  0.040085  0.034740  0.042140  0.086104  0.035932  0.035932
# .VPD_T1_47_1_gfXG-1    0.045483  0.045483  0.054248  0.065969  0.047364  0.069805  0.085912  0.072555  0.072555
# VPD_T1_47_1_gfXG       0.032582  0.032582  0.047737  0.060582  0.034294  0.057209  0.075684  0.060676  0.060676
# .HOUR_COS              0.030291  0.030291  0.027544  0.032349  0.037877  0.025664  0.025688  0.026822  0.026822
# .HOUR_SIN              0.029683  0.029683  0.023081  0.029640  0.032559  0.041195  0.047190  0.027877  0.027877
# .TA_T1_47_1_gfXG-1     0.028208  0.028208  0.031536  0.033481  0.040005  0.060062  0.039088  0.035667  0.035667
# .WEEK_SIN              0.017378  0.017378  0.004989  0.004870  0.016384  0.046647  0.008275  0.004376  0.004376
# .YEARDOY               0.016580  0.016580  0.016363  0.012082  0.015254  0.016635  0.026595  0.016338  0.016338
# .YEARWEEK              0.005917  0.005917  0.003852  0.003878  0.004066  0.004945  0.004706  0.003541  0.003541
# .SEASON_COS            0.004783  0.004783  0.072342  0.035039  0.065826  0.051423  0.044154  0.004477  0.004477
# .MONTH_SIN             0.001131  0.001131  0.006686  0.000985  0.001999  0.002651  0.005518  0.014703  0.014703
# .YEARMONTH             0.001029  0.001029  0.001014  0.001342  0.001915  0.001553  0.001422  0.001195  0.001195
# .MONTH_COS             0.000831  0.000831  0.001510  0.002128  0.000925  0.001118  0.001068  0.002149  0.002149
# .YEAR                  0.000386  0.000386  0.000406  0.000416  0.000421  0.000435  0.000363  0.000266  0.000266
# .SEASON_SIN            0.000129  0.000129  0.000098  0.000380  0.000257  0.000180  0.000238  0.000227  0.000227

# %% [markdown]
# ## Names of gap-filled variables

# %%
print("Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:")
fpc.report_gapfilling_variables()
# Out:
# Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:
# long_term_random_forest (NONE): LE_L3.1_L3.3_NONE_QCF -> LE_L3.1_L3.3_NONE_QCF_gfRF

# %%
gapfilled_names = fpc.get_gapfilled_names()
gapfilled_names
# Out:
# ['LE_L3.1_L3.3_NONE_QCF_gfRF']

# %% [markdown]
# Gap-filled data can also be accessed directly. To get all gap-filled variables and also the same variables before gap-filling in a dataframe, use `.get_gapfilled_variables()`:

# %%
gapfilled_vars = fpc.get_gapfilled_variables()
gapfilled_vars.head(3)
# Out:
#                      LE_L3.1_L3.3_NONE_QCF_gfRF  LE_L3.1_L3.3_NONE_QCF
# TIMESTAMP_MIDDLE
# 2016-01-01 00:15:00                   -1.583467                    NaN
# 2016-01-01 00:45:00                   -1.583467                    NaN
# 2016-01-01 01:15:00                   -1.011555                    NaN

# %% [markdown]
# The names of the flux that was gap-filled can be accessed like this:

# %%
nongapfilled_names = fpc.get_nongapfilled_names()
nongapfilled_names
# Out:
# ['LE_L3.1_L3.3_NONE_QCF']

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Heatmaps

# %%
fpc.showplot_gapfilled_heatmap()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py:502: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Cumulatives per year

# %%
fpc.showplot_gapfilled_cumulative(gain=1, units=r'($\mathrm{W\ m^{-2}}$)', per_year=True)
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:145: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# ### Cumulative across all data

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=False)
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:251: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# ### ML Feature ranks per year (machine learning models only)

# %%
fpc.showplot_feature_ranks_per_year()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:268: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(row.index, row.values, "o", marker=verts, ms=20,
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:287: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### MDS gap-filling qualities (MDS only, otherwise skipped)

# %%
fpc.showplot_mds_gapfilling_qualities()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # SAVE RESULTS TO FILE

# %% [markdown]
# - Save results to file for futher processing
# - This can be useful if you want to use the data in another software, e.g. continuing post-processing using the library `ReddyProc` in `R`
# - `Parquet` format is recommended for large datasets

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Save complete data (input data and results) to CSV (large and slow)

# %%
# results.to_csv("FluxProcessingChain_L4.1.csv")

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Save input data and results to Parquet (small and fast)
# - Needed if you want to continue post-processing in notebooks
# - Can also be used in `R` with the `arrow` package

# %%
save_parquet(data=results, filename="14_FPC_IRGA72_LE-QCF11-USTNONE-L4.1-RF")
# Out:
# Saved file 14_FPC_IRGA72_LE-QCF11-USTNONE-L4.1-RF.parquet (3.825 seconds).
# '14_FPC_IRGA72_LE-QCF11-USTNONE-L4.1-RF.parquet'

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # ✅END OF NOTEBOOK

# %% [markdown]
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2025-12-02 14:07:55
