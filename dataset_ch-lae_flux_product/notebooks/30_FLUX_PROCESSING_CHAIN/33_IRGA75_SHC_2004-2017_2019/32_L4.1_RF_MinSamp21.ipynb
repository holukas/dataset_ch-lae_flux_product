# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Flux Processing Chain (here starting Level-4.1)
# </b>
# </br>
#
# </span>
# <p>Post-processing of EddyPro <i>_fluxnet_</i> output files</p>

# %% [markdown]
# ---
# **Notebook version**: `11.0` (19 Nov 2025)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %%
from datetime import datetime

# %% [markdown]
# </br>

# %% [markdown]
# # Load previous `fpc` instance

# %%
import pickle
# 1. Load the instance from the pickle file
file_path = '31_fpcInstance_QCF11+TrimNT-5.pkl'
with open(file_path, 'rb') as file:
    fpc = pickle.load(file)

# %%
fpc

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🟢Level-4.1: GAP-FILLING

# %% [markdown]
# - Introduced in `diive` v0.85.0, gap-filling can now be done using both random forest and MDS
# - For gap-filling using MDS, make sure that variables are in the required units: short-wave incoming radiation in `W m-2`, air temperature in `°C`, VPD in `hPa`
#
# Parameters:
# - `mds_settings` are parameters for the MDS gap-filling method, [see docstring here for more details](https://github.com/holukas/diive/blob/main/diive/pkgs/gapfilling/mds.py)
# - `rf_settings` are parameters for scikit's `RandomForestRegressor` model, [see their official documentation for allowed parameters](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# - `ml_feature_settings` are general settings for machine-learning models (such as random forest)

# %% [markdown]
# ## 🔸Long-term random forest

# %%
FEATURES = ["TA_T1_47_1_gfXG", "SW_IN_T1_47_1_gfXG", "VPD_T1_47_1_gfXG"]
fpc.level41_longterm_random_forest(
    features=FEATURES,
    sanitize_timestamp=True,
    features_lag=[-1, 1],
    features_lag_stepsize=1,
    features_lag_exclude_cols=None,
    reduce_features=False,
    vectorize_timestamps=True,
    add_continuous_record_number=True,
    perm_n_repeats=10,
    verbose=True,
    n_estimators=100,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    n_jobs=1,
    random_state=42,
)
# Out:
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
#
# Adding new data columns ...
# ++ Added new columns with lagged variants for: ['TA_T1_47_1_gfXG', 'SW_IN_T1_47_1_gfXG', 'VPD_T1_47_1_gfXG'] (lags between -1 and 1 with stepsize 1), no lagged variants for: ['NEE_L3.1_L3.3_CUT_50_QCF']. Shifting the time series created gaps which were then filled with the nearest value.
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
# ++ Added new column .RECORDNUMBER with record numbers from 1 to 276211.
#
# Sanitizing timestamp ...
# >>> Validating timestamp naming of timestamp column TIMESTAMP_MIDDLE ... Timestamp name OK.
# >>> Converting timestamp TIMESTAMP_MIDDLE to datetime ... OK
# >>> All rows have timestamp TIMESTAMP_MIDDLE, no rows removed.
# >>> Sorting timestamp TIMESTAMP_MIDDLE ascending ...
# >>> Removing data records with duplicate indexes ... OK (no duplicates found in timestamp index)
# >>> Creating continuous <30 * Minutes> timestamp index for timestamp TIMESTAMP_MIDDLE between 2004-03-30 14:45:00 and 2019-12-31 23:45:00 ...
# (!)Some features are incomplete and have less than 276211 values:
#     --> TA_T1_47_1_gfXG (267867 values)
#     --> SW_IN_T1_47_1_gfXG (267867 values)
#     --> VPD_T1_47_1_gfXG (267867 values)
#     --> .TA_T1_47_1_gfXG-1 (267866 values)
#     --> .TA_T1_47_1_gfXG+1 (267867 values)
#     --> .SW_IN_T1_47_1_gfXG-1 (267866 values)
#     --> .SW_IN_T1_47_1_gfXG+1 (267867 values)
#     --> .VPD_T1_47_1_gfXG-1 (267866 values)
#     --> .VPD_T1_47_1_gfXG+1 (267867 values)
# This means that not all target values can be predicted based on the full model.
# [neighboring_years] Assigned [2004, 2005, 2006] to data pool for 2004.
# [neighboring_years] Assigned [2004, 2005, 2006] to data pool for 2005.
# [neighboring_years] Assigned [2005, 2006, 2007] to data pool for 2006.
# [neighboring_years] Assigned [2006, 2007, 2008] to data pool for 2007.
# [neighboring_years] Assigned [2007, 2008, 2009] to data pool for 2008.
# [neighboring_years] Assigned [2008, 2009, 2010] to data pool for 2009.
# [neighboring_years] Assigned [2009, 2010, 2011] to data pool for 2010.
# [neighboring_years] Assigned [2010, 2011, 2012] to data pool for 2011.
# [neighboring_years] Assigned [2011, 2012, 2013] to data pool for 2012.
# [neighboring_years] Assigned [2012, 2013, 2014] to data pool for 2013.
# [neighboring_years] Assigned [2013, 2014, 2015] to data pool for 2014.
# [neighboring_years] Assigned [2014, 2015, 2016] to data pool for 2015.
# [neighboring_years] Assigned [2015, 2016, 2017] to data pool for 2016.
# [neighboring_years] Assigned [2016, 2017, 2018] to data pool for 2017.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2018.
# [neighboring_years] Assigned [2017, 2018, 2019] to data pool for 2019.
# Initializing model for 2004 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# (!)Some features are incomplete and have less than 48307 values:
#     --> TA_T1_47_1_gfXG (39963 values)
#     --> SW_IN_T1_47_1_gfXG (39963 values)
#     --> VPD_T1_47_1_gfXG (39963 values)
#     --> .TA_T1_47_1_gfXG-1 (39962 values)
#     --> .TA_T1_47_1_gfXG+1 (39964 values)
#     --> .SW_IN_T1_47_1_gfXG-1 (39962 values)
#     --> .SW_IN_T1_47_1_gfXG+1 (39964 values)
#     --> .VPD_T1_47_1_gfXG-1 (39962 values)
#     --> .VPD_T1_47_1_gfXG+1 (39964 values)
# This means that not all target values can be predicted based on the full model.
# Initializing model for 2005 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# (!)Some features are incomplete and have less than 48307 values:
#     --> TA_T1_47_1_gfXG (39963 values)
#     --> SW_IN_T1_47_1_gfXG (39963 values)
#     --> VPD_T1_47_1_gfXG (39963 values)
#     --> .TA_T1_47_1_gfXG-1 (39962 values)
#     --> .TA_T1_47_1_gfXG+1 (39964 values)
#     --> .SW_IN_T1_47_1_gfXG-1 (39962 values)
#     --> .SW_IN_T1_47_1_gfXG+1 (39964 values)
#     --> .VPD_T1_47_1_gfXG-1 (39962 values)
#     --> .VPD_T1_47_1_gfXG+1 (39964 values)
# This means that not all target values can be predicted based on the full model.
# Initializing model for 2006 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2007 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2008 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2009 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2010 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2011 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2012 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2013 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2014 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2015 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2016 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2017 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# Initializing model for 2018 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# (!)Some features are incomplete and have less than 52560 values:
#     --> .TA_T1_47_1_gfXG+1 (52559 values)
#     --> .SW_IN_T1_47_1_gfXG+1 (52559 values)
#     --> .VPD_T1_47_1_gfXG+1 (52559 values)
# This means that not all target values can be predicted based on the full model.
# Initializing model for 2019 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# ============================================================
# (!)Some features are incomplete and have less than 52560 values:
#     --> .TA_T1_47_1_gfXG+1 (52559 values)
#     --> .SW_IN_T1_47_1_gfXG+1 (52559 values)
#     --> .VPD_T1_47_1_gfXG+1 (52559 values)
# This means that not all target values can be predicted based on the full model.
#
# Training model for 2004 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2004-09-20 11:45:00 and 2006-12-31 21:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2004 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 39962 records.
# >>> Collecting results for final model ...
# >>> Filling 26254 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 8345 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model is trained on NEE_L3.1_L3.3_CUT_50_QCF_gfRF and timestamp info ...
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK'] (ONLY FALLBACK)
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2005 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2004-09-20 11:45:00 and 2006-12-31 21:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2005 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 39962 records.
# >>> Collecting results for final model ...
# >>> Filling 26254 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 8345 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model is trained on NEE_L3.1_L3.3_CUT_50_QCF_gfRF and timestamp info ...
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK'] (ONLY FALLBACK)
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2006 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2005-01-01 11:15:00 and 2007-12-31 09:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2006 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 33381 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2007 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2006-01-03 11:45:00 and 2008-12-31 14:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2007 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 32508 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2008 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2007-01-01 13:45:00 and 2009-12-31 20:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2008 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 32301 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2009 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2008-01-01 10:45:00 and 2010-12-31 12:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2009 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 33182 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2010 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2009-01-01 18:45:00 and 2011-12-31 02:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2010 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 33552 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2011 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2010-01-02 07:15:00 and 2012-12-31 21:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2011 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34497 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2012 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2011-01-01 07:45:00 and 2013-12-31 23:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2012 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 34780 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2013 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2012-01-01 12:15:00 and 2014-12-31 20:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2013 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 35185 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2014 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2013-01-01 01:15:00 and 2015-12-31 09:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2014 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52560 records.
# >>> Collecting results for final model ...
# >>> Filling 34447 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2015 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2014-01-01 11:45:00 and 2016-12-31 01:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2015 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 33892 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2016 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2015-01-01 08:45:00 and 2017-12-12 08:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2016 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 33609 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2017 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2016-01-01 08:45:00 and 2017-12-12 07:15:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2017 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52608 records.
# >>> Collecting results for final model ...
# >>> Filling 39926 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 0 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model not necessary, all gaps were already filled.
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2018 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 06:45:00 and 2019-03-20 12:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2018 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52559 records.
# >>> Collecting results for final model ...
# >>> Filling 44994 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 1 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model is trained on NEE_L3.1_L3.3_CUT_50_QCF_gfRF and timestamp info ...
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK'] (ONLY FALLBACK)
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Combining predictions from full model and fallback model ...
#
# Training model for 2019 ...
#
# Training final model ...
# >>> Training model <class 'sklearn.ensemble._forest.RandomForestRegressor'> based on data between 2017-01-01 06:45:00 and 2019-03-20 12:45:00 ...
# >>> Fitting model to training data ...
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate permutation importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2019 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate permutation importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 52559 records.
# >>> Collecting results for final model ...
# >>> Filling 44994 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfRF ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 1 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Fallback model is trained on NEE_L3.1_L3.3_CUT_50_QCF_gfRF and timestamp info ...
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK'] (ONLY FALLBACK)
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF_gfRF using fallback model ...
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2004 ...
# Collecting results for 2005 ...
# Collecting results for 2006 ...
# Collecting results for 2007 ...
# Collecting results for 2008 ...
# Collecting results for 2009 ...
# Collecting results for 2010 ...
# Collecting results for 2011 ...
# Collecting results for 2012 ...
# Collecting results for 2013 ...
# Collecting results for 2014 ...
# Collecting results for 2015 ...
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:297: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self._gapfilling_df = pd.concat([self._gapfilling_df, rfts.gapfilling_df_[keepyear]], axis=0)
# Collecting results for 2016 ...
# Collecting results for 2017 ...
# Collecting results for 2018 ...
# Collecting results for 2019 ...

# %% [markdown]
# ## 🔸MDS (Marginal Distribution Sampling)

# %%
# fpc.level41_mds(
#     swin="SW_IN_T1_47_1_gfXG",
#     ta="TA_T1_47_1_gfXG",
#     vpd="VPD_T1_47_1_gfXG",
#     swin_tol=[20, 50],
#     ta_tol=2.5,
#     vpd_tol=0.5,
#     avg_min_n_vals=5
# )

# %% [markdown]
# ## Get results
# - Results from the flux processing chain can be accessed using `.get_data()`
# - This returns a dataframe containing all input data and all newly generated variables, such as quality flags, quality-filtered fluxes and gap-filled fluxes

# %%
# results = fpc.get_data(verbose=1)
# results

# %% [markdown]
# ## Model scores

# %% [markdown]
# ### Model scores and details on test data

# %%
# Show train/test details
print(fpc.report_traintest_model_scores())
print(fpc.report_traintest_details())
# fpc.report_traintest_model_scores(outpath=".")  # Save in current folder
# fpc.report_traintest_details(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES from TRAINING/TESTING (long_term_random_forest):
#  trained on training data, tested on unseen test data CUT_50
#             2004       2005       2006       2007       2008       2009  ...       2014       2015       2016       2017       2018       2019
# mae     3.516057   3.516057   3.617611   3.678955   3.624869   3.685698  ...   4.692638   4.725127   4.488085   4.583646   4.047202   4.047202
# medae   2.283618   2.283618   2.297869   2.349195   2.287725   2.408070  ...   2.988044   2.847827   2.774487   2.808388   2.637111   2.637111
# mse    27.138237  27.138237  29.832485  30.974761  29.750083  29.857527  ...  49.635110  52.797550  46.260045  48.623413  35.740690  35.740690
# rmse    5.209437   5.209437   5.461912   5.565497   5.454364   5.464204  ...   7.045219   7.266192   6.801474   6.973049   5.978352   5.978352
# mape    2.669111   2.669111  11.983759   2.892862   3.627066   3.054217  ...   2.188632   9.954378   2.233272   2.282320   4.463796   4.463796
# maxe   41.086693  41.086693  47.689293  46.660257  49.819563  41.010826  ...  45.693915  54.295379  43.646086  44.397319  38.581622  38.581622
# r2      0.615055   0.615055   0.617563   0.657167   0.697495   0.687632  ...   0.594696   0.591828   0.635963   0.632111   0.648154   0.648154
#
# [7 rows x 16 columns]
# None
#
# DETAILS from TRAINING/TESTING (long_term_random_forest CUT_50):
#  trained on training data, tested on unseen test data
#                                                         2004                                               2005                                               2006                                               2007                                               2008                                               2009  ...                                               2014                                               2015                                               2016                                               2017                                               2018                                               2019
# train_df                        TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...  ...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_df                         TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...  ...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...                       TA_T1_47_1_gfXG  SW_IN_T1...
# test_size                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25  ...                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25                                               0.25
# X_names    [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  ...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...  [TA_T1_47_1_gfXG, SW_IN_T1_47_1_gfXG, VPD_T1_4...
# model      (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  ...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...  (DecisionTreeRegressor(max_features=1.0, rando...
#
# [5 rows x 16 columns]
# None

# %% [markdown]
# ### Model scores on all data

# %%
fpc.report_gapfilling_model_scores()
# fpc.report_gapfilling_model_scores(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES (long_term_random_forest): CUT_50
#             2004       2005       2006       2007       2008       2009  ...       2014       2015       2016       2017       2018       2019
# mae     1.876593   1.876593   1.907675   1.938353   1.968280   1.976584  ...   2.446303   2.465631   2.370520   2.378824   2.121472   2.121472
# medae   1.080166   1.080166   1.072013   1.066738   1.111001   1.102269  ...   1.345768   1.353971   1.303504   1.291209   1.194616   1.194616
# mse     9.685495   9.685495  10.450246  10.966331  10.945133  10.889236  ...  17.287764  18.137316  16.390151  16.817476  12.625023  12.625023
# rmse    3.112153   3.112153   3.232684   3.311545   3.308343   3.299884  ...   4.157856   4.258793   4.048475   4.100912   3.553171   3.553171
# mape    2.953872   2.953872   3.847020   2.236824   1.568905   1.505577  ...   2.975837   3.242634   1.702139   1.773869   1.828524   1.828524
# maxe   41.086693  41.086693  47.689293  46.660257  49.819563  41.010826  ...  45.693915  54.295379  43.646086  44.397319  38.581622  38.581622
# r2      0.861367   0.861367   0.870093   0.875965   0.889077   0.889680  ...   0.856478   0.858477   0.868697   0.868003   0.873327   0.873327
#
# [7 rows x 16 columns]

# %% [markdown]
# During long-term gap-filling, different years are pooled together to predict one central year, i.e., multiple models are used.
# The used data pools can be display with:

# %%
fpc.report_gapfilling_poolyears()
# Out:
# DATA POOLS USED FOR MACHINE-LEARNING GAP-FILLING:
# 2004: long_term_random_forest used data from [2004, 2005, 2006] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2005: long_term_random_forest used data from [2004, 2005, 2006] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2006: long_term_random_forest used data from [2005, 2006, 2007] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2007: long_term_random_forest used data from [2006, 2007, 2008] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2008: long_term_random_forest used data from [2007, 2008, 2009] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2009: long_term_random_forest used data from [2008, 2009, 2010] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2010: long_term_random_forest used data from [2009, 2010, 2011] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2011: long_term_random_forest used data from [2010, 2011, 2012] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2012: long_term_random_forest used data from [2011, 2012, 2013] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2013: long_term_random_forest used data from [2012, 2013, 2014] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2014: long_term_random_forest used data from [2013, 2014, 2015] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2015: long_term_random_forest used data from [2014, 2015, 2016] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2016: long_term_random_forest used data from [2015, 2016, 2017] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2017: long_term_random_forest used data from [2016, 2017, 2018] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2018: long_term_random_forest used data from [2017, 2018, 2019] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF
# 2019: long_term_random_forest used data from [2017, 2018, 2019] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfRF

# %%
fpc.report_gapfilling_feature_importances()  # Save in current folder
# fpc.report_gapfilling_feature_importances(outpath=".")  # Save in current folder
# Out:
# FEATURE IMPORTANCES (long_term_random_forest): CUT_50
# YEAR                       2004      2005      2006      2007      2008      2009  ...      2014      2015      2016      2017      2018      2019
# FEATURE                                                                            ...
# .DOY_COS               0.601920  0.601920  0.236795  0.409096  0.521563  0.212359  ...  0.509961  0.511178  0.626124  0.243788  0.335346  0.335346
# SW_IN_T1_47_1_gfXG     0.321167  0.321167  0.397992  0.503324  0.463162  0.371044  ...  0.461879  0.511615  0.431290  0.728224  0.457792  0.457792
# .SW_IN_T1_47_1_gfXG+1  0.285523  0.285523  0.308379  0.061686  0.066761  0.053575  ...  0.058275  0.075721  0.076107  0.076146  0.078429  0.078429
# .HOUR_COS              0.226684  0.226684  0.335397  0.312025  0.182797  0.201397  ...  0.178403  0.178054  0.242481  0.217590  0.225585  0.225585
# .SW_IN_T1_47_1_gfXG-1  0.198760  0.198760  0.133655  0.140492  0.137808  0.205869  ...  0.164575  0.126086  0.104367  0.067718  0.089659  0.089659
# .DOY_SIN               0.163660  0.163660  0.090219  0.090046  0.055849  0.036875  ...  0.098463  0.066118  0.077111  0.067872  0.046518  0.046518
# .VPD_T1_47_1_gfXG-1    0.090608  0.090608  0.156793  0.141674  0.100645  0.082775  ...  0.103357  0.107230  0.104321  0.110783  0.096840  0.096840
# VPD_T1_47_1_gfXG       0.074528  0.074528  0.041983  0.043035  0.044277  0.037565  ...  0.044488  0.040414  0.040768  0.037947  0.033107  0.033107
# .VPD_T1_47_1_gfXG+1    0.063675  0.063675  0.073019  0.064150  0.071663  0.069122  ...  0.060103  0.061193  0.064767  0.045483  0.058863  0.058863
# .TA_T1_47_1_gfXG+1     0.050406  0.050406  0.047506  0.039150  0.035006  0.037974  ...  0.034576  0.028149  0.035435  0.036695  0.055661  0.055661
# .TA_T1_47_1_gfXG-1     0.041430  0.041430  0.039271  0.035279  0.029757  0.035405  ...  0.048609  0.033721  0.031479  0.033573  0.045969  0.045969
# .RECORDNUMBER          0.036233  0.036233  0.056711  0.038947  0.036504  0.030355  ...  0.063441  0.046018  0.038327  0.053702  0.097016  0.097016
# .HOUR_SIN              0.035981  0.035981  0.038594  0.025652  0.021100  0.023857  ...  0.022831  0.025588  0.026358  0.021480  0.022683  0.022683
# TA_T1_47_1_gfXG        0.025698  0.025698  0.024275  0.023819  0.022895  0.021809  ...  0.026250  0.021979  0.027453  0.023970  0.027956  0.027956
# .WEEK_COS              0.019761  0.019761  0.102969  0.022093  0.014462  0.110964  ...  0.011355  0.021433  0.029980  0.102996  0.091134  0.091134
# .YEARDOY               0.013355  0.013355  0.017372  0.014326  0.012295  0.011595  ...  0.018572  0.014771  0.014313  0.012188  0.012793  0.012793
# .WEEK_SIN              0.009201  0.009201  0.011339  0.018470  0.014355  0.020081  ...  0.009441  0.011519  0.016951  0.005771  0.005094  0.005094
# .YEARWEEK              0.005587  0.005587  0.005498  0.005346  0.005833  0.004620  ...  0.006288  0.006090  0.006358  0.005278  0.002897  0.002897
# .SEASON_COS            0.003539  0.003539  0.002000  0.005424  0.001460  0.005508  ...  0.001161  0.001197  0.000809  0.003072  0.003178  0.003178
# .MONTH_COS             0.002587  0.002587  0.004396  0.003778  0.003270  0.003439  ...  0.004703  0.005685  0.006034  0.003501  0.004311  0.004311
# .MONTH_SIN             0.001823  0.001823  0.001460  0.004461  0.006081  0.083988  ...  0.003662  0.002265  0.004955  0.010239  0.002665  0.002665
# .YEARMONTH             0.001813  0.001813  0.002127  0.002366  0.002971  0.001846  ...  0.002399  0.002187  0.002336  0.001704  0.000863  0.000863
# .YEAR                  0.000579  0.000579  0.000858  0.001133  0.000740  0.000605  ...  0.000862  0.000723  0.000871  0.000484  0.000161  0.000161
# .SEASON_SIN            0.000405  0.000405  0.000427  0.000440  0.000472  0.000441  ...  0.000469  0.000316  0.000708  0.000538  0.000493  0.000493
#
# [24 rows x 16 columns]

# %% [markdown]
# ## Names of gap-filled variables

# %%
print("Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:")
fpc.report_gapfilling_variables()
# Out:
# Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:
# long_term_random_forest (CUT_50): NEE_L3.1_L3.3_CUT_50_QCF -> NEE_L3.1_L3.3_CUT_50_QCF_gfRF

# %%
gapfilled_names = fpc.get_gapfilled_names()
gapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF_gfRF']

# %% [markdown]
# Gap-filled data can also be accessed directly. To get all gap-filled variables and also the same variables before gap-filling in a dataframe, use `.get_gapfilled_variables()`:

# %%
gapfilled_vars = fpc.get_gapfilled_variables()
gapfilled_vars.head(3)
# Out:
#                      NEE_L3.1_L3.3_CUT_50_QCF_gfRF  NEE_L3.1_L3.3_CUT_50_QCF
# TIMESTAMP_MIDDLE
# 2004-03-30 14:45:00                      -1.091496                       NaN
# 2004-03-30 15:15:00                      -1.538040                       NaN
# 2004-03-30 15:45:00                      -1.538040                       NaN

# %% [markdown]
# The names of the flux that was gap-filled can be accessed like this:

# %%
nongapfilled_names = fpc.get_nongapfilled_names()
nongapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF']

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Heatmaps

# %%
fpc.showplot_gapfilled_heatmap()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py:502: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Cumulatives per year

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=True)
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:145: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# ### Cumulative across all data

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=False)
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:251: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()

# %% [markdown]
# ### ML Feature ranks per year (machine learning models only)

# %%
fpc.showplot_feature_ranks_per_year()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:268: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(row.index, row.values, "o", marker=verts, ms=20,
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\gapfilling\longterm.py:287: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### MDS gap-filling qualities (MDS only, otherwise skipped)

# %%
fpc.showplot_mds_gapfilling_qualities()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # SAVE RESULTS TO FILE

# %% [markdown]
# - Save results to file for futher processing
# - This can be useful if you want to use the data in another software, e.g. continuing post-processing using the library `ReddyProc` in `R`
# - `Parquet` format is recommended for large datasets

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Save complete data (input data and results) to CSV (large and slow)

# %%
# results.to_csv("FluxProcessingChain_L4.1.csv")

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Save input data and results to Parquet (small and fast)
# - Needed if you want to continue post-processing in notebooks
# - Can also be used in `R` with the `arrow` package

# %%
# save_parquet(data=results, filename="02_FirstResults_FluxProcessingChain_L4.1")

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # ✅END OF NOTEBOOK

# %% [markdown]
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2025-12-01 17:52:03
